# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\anaconda\anaconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\anaconda\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
data = pd.read_excel(r"C:\Users\sarvesh jathar\Downloads\PAN+Card+Validation+in+PYTHON+-+Scripts\PAN Card Validation in PYTHON - Scripts\PAN Number Validation Dataset.xlsx")
data.head()

# %%
total_records = len(data)

# %%
print(f'The dataset has {data.shape[0]} rows and {data.shape[1]} row')
# Out:
# The dataset has 10000 rows and 1 row

# %%
data['Pan_Numbers'] = data['Pan_Numbers'].astype('string')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Pan_Numbers  9035 non-null   string
# dtypes: string(1)
# memory usage: 78.3 KB

# %%
data['Pan_Numbers'] = data['Pan_Numbers'].astype('string').str.strip().str.upper()

# %%
data.head()
# Out:
#   Pan_Numbers
# 0  VGLOD3180G
# 1  PHOXD7232L
# 2  MGEPH6532A
# 3  JJCHK4574O
# 4  XTQIJ2330L

# %%
data[data['Pan_Numbers'] == '']
# Out:
#      Pan_Numbers
# 5019
# 5020

# %%
data.isnull().sum()
# Out:
# Pan_Numbers    965
# dtype: int64

# %%
data = data.replace({'Pan_Numbers' : ''}, pd.NA)

# %%
data = data.dropna()

# %%
data.shape
# Out:
# (9033, 1)

# %%
data.duplicated().sum()
# Out:
# 8

# %%
data['Pan_Numbers'].nunique()
# Out:
# 9025

# %%
data.drop_duplicates(inplace = True)

# %%
data.shape
# Out:
# (9025, 1)

# %%
def has_adjacent_repitition(pan):
    # for i in range(len(pan)-1):
    #     if pan[i] == pan[i+1]:
    #         return True
    # return False
    return any(pan[i] == pan[i+1] for i in range(len(pan)-1))

print(has_adjacent_repitition('ABCDE'))
print(has_adjacent_repitition('AABCD'))
# Out:
# False
# True

# %%
def is_sequential(pan):
    # for i in range(len(pan)-1):
    #     if ord(pan[i+1]) - ord(pan[i]) !=1:
    #         return False
    # return True
    return all(ord(pan[i+1]) - ord(pan[i]) == 1 for i in range(len(pan)-1))

print(is_sequential('ABCDO'))
print(is_sequential('MNOPQ'))
print(is_sequential('AAAAA'))
# Out:
# False
# True
# False

# %%
import re

# %%
def is_pan_valid(pan):
    if len(pan) != 10:
        return False

    if not re.match(r'^[A-Z]{5}[0-9]{4}[A-Z]$', pan):
        return False

    if has_adjacent_repitition(pan):
        return False

    if is_sequential(pan):
        return False
    return True

# %%
data['Status'] = data["Pan_Numbers"].apply(
    lambda x: "Valid" if is_pan_valid(x) else "Invalid"
)

# %%
data.head()
# Out:
#   Pan_Numbers   Status
# 0  VGLOD3180G    Valid
# 1  PHOXD7232L    Valid
# 2  MGEPH6532A    Valid
# 3  JJCHK4574O  Invalid
# 4  XTQIJ2330L  Invalid

# %%
data['Status'].unique()
# Out:
# array(['Valid', 'Invalid'], dtype=object)
